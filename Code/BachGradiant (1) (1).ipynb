# %% [markdown]
# # hꝊ(x) = Ꝋ0 + Ꝋ1 * x
#
# ![image.png](attachment:image.png))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'C:\\Users\\Elmasry\\Desktop\\Data.txt'
data = pd.read_csv(path, header=None, names=['Population', 'Profit'])

# %%
#show data details
print('data = \n' ,data.head(10) )
print('**************************************')
print('data.describe = \n',data.describe())
print('**************************************')
#draw data
# Out:
# data =
#     Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233
# 5      8.3829  11.8860
# 6      7.4764   4.3483
# 7      8.5781  12.0000
# 8      6.4862   6.5987
# 9      5.0546   3.8166
# **************************************
# data.describe =
#         Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000
# **************************************

# %%
# adding a new column called ones before the data
data.insert(0, 'Ones', 1)
print('new data = \n' ,data.head(10) )
# Out:
# new data =
#     Ones  Population   Profit
# 0     1      6.1101  17.5920
# 1     1      5.5277   9.1302
# 2     1      8.5186  13.6620
# 3     1      7.0032  11.8540
# 4     1      5.8598   6.8233
# 5     1      8.3829  11.8860
# 6     1      7.4764   4.3483
# 7     1      8.5781  12.0000
# 8     1      6.4862   6.5987
# 9     1      5.0546   3.8166

# %%
X = data.iloc[:,0:-1]
y = data.iloc[:,-1:]

# %%
X
# Out:
#     Ones  Population
# 0      1      6.1101
# 1      1      5.5277
# 2      1      8.5186
# 3      1      7.0032
# 4      1      5.8598
# ..   ...         ...
# 92     1      5.8707
# 93     1      5.3054
# 94     1      8.2934
# 95     1     13.3940
# 96     1      5.4369
#
# [97 rows x 2 columns]

# %%
y
# Out:
#       Profit
# 0   17.59200
# 1    9.13020
# 2   13.66200
# 3   11.85400
# 4    6.82330
# ..       ...
# 92   7.20290
# 93   1.98690
# 94   0.14454
# 95   9.05510
# 96   0.61705
#
# [97 rows x 1 columns]

# %%
X = np.matrix(X.values)
y = np.matrix(y.values)
theta = np.matrix(np.array([0,0]))

# %%
theta
# Out:
# matrix([[0, 0]])

# %%
X[:10,:]
# Out:
# matrix([[1.    , 6.1101],
#         [1.    , 5.5277],
#         [1.    , 8.5186],
#         [1.    , 7.0032],
#         [1.    , 5.8598],
#         [1.    , 8.3829],
#         [1.    , 7.4764],
#         [1.    , 8.5781],
#         [1.    , 6.4862],
#         [1.    , 5.0546]])

# %%
y[:10,:]
# Out:
# matrix([[17.592 ],
#         [ 9.1302],
#         [13.662 ],
#         [11.854 ],
#         [ 6.8233],
#         [11.886 ],
#         [ 4.3483],
#         [12.    ],
#         [ 6.5987],
#         [ 3.8166]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def computeCost(X, y, theta):
    
    z = np.power(((X * theta.T) - y), 2)
    return np.sum(z) / (2 * len(X))
print('computeCost(X, y, theta) = ' , computeCost(X, y, theta))
# Out:
# computeCost(X, y, theta) =  32.072733877455676

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def gradientDescent(X, y, theta, alpha, epoch,parameters):
    
    temp = np.matrix(np.zeros(theta.shape))
    
    for i in range(epoch):
       
        error = (X* theta.T) - y
            
        for j in range(parameterTheta):
                term = np.multiply(error, X[:,j])
                temp[0,j] = theta[0,j] - ((alpha / len(X)) * np.sum(term))
        theta = temp
   
        
    return theta

# %%
alpha = 0.01
epoch = 2000
parameterTheta=2

# perform gradientDescent to "fit" the model parameters
g = gradientDescent(X, y, theta, alpha, epoch,parameterTheta)

# %%
g
# Out:
# matrix([[-3.78806857,  1.18221277]])

# %%
print('computeCost = ' , computeCost(X, y, g))
# Out:
# computeCost =  4.4780276098799705
